# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 1
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print("""¿Por qué está magnífica tecnología científica,\
\n\t que ahorra trabajo y nos hace la vida más fácil,\
nos aporta tan poca felicidad?\n\t\t la respuesta es está,\
simplemente: porque aún no hemos aprendido a usarla con tino.""")
print('"Albert Einstein"')
# Out:
# ¿Por qué está magnífica tecnología científica,
# 	 que ahorra trabajo y nos hace la vida más fácil,nos aporta tan poca felicidad?
# 		 la respuesta es está,simplemente: porque aún no hemos aprendido a usarla con tino.
# "Albert Einstein"

# %%
# Out:
# abc\\def

# %% [markdown]
# ## Ejercicio 2
# 1. Escribe el nombre de la calle de tu domicilio
# 2. Escribe el numero de la calle en otra
# 3. Población en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Crea una quinta variable que concatene todas ellas
# 6. Imprimela por pantalla

# %%
domicilio1 = "Calle corralillo "
calle = "8 " 
Población = "Marchamalo " 
CP = "19180 " 
print(domicilio1 + calle + Población + CP) 
Dirección = ( domicilio1 + calle +
# Out:
# Calle corralillo 8 Marchamalo 19180

# %% [markdown]
# ## Ejercicio 3
# Replica el output del ejercicio dos, pero está vez sin usar una variable intermedia que concatene todas las demas. Realiza este ejercicio en una línea, con un  único `print`

# %%
print('1. Calle Corralillo,\
\n2. 8,\
\n3. Marchamalo,\
\n4. 19180')
# Out:
# 1. Calle Corralillo,
# 2. 8,
# 3. Marchamalo,
# 4. 19180

# %% [markdown]
# ## Ejercicio 4
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. exec = True
# 6. import = 40
# 7. 81mi_variable = "Agua"
# 8. mi_variable10 = 6

# %% [markdown]
# 1. Mi_variable = Economía" <span style="color:green">Bien</span>
# 2. otra_var = "Ejercicio  <span style="color:red">Mal</span> Falta las comillas (") al final.
# 3. True = "Ejercicio" <span style="color:green">Bien</span>
# 4. mi variab1e = "Alpha" <span style="color:red">Mal</span> Mi_variab1e y falta cerrar comillas
# 5. exec = True <span style="color:red">Mal</span> faltan las comillas
# 6. import = 40 <span style="color:red">Mal</span> import es un comando.
# 7. 81mi_variable = "Agua" <span style="color:red">Mal</span> No puede comenzar la variable por numeros
# 8. mi_variable10 = 6 <span style="color:red">Mal</span> Faltan las comillas

# %%
mi_variable = "Economía"
otra_var = "Ejercicio
True = "Ejercicio"
mi variab1e = "Alpha"
exec = True
import = 40
81mi_variable = "Agua"
mi_variable10 = 6
# Out:
#   Cell In[84], line 2
#     otra_var = "Ejercicio
#                ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# ## Ejercicio 5
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = (C × 9 / 5) + 32

# %%
C = float(input("¿Cuantos grados celcius deseas convertir?")) #Por favor agregar un valor al input antes de seguir programando porque x_x
F = (C * 9/5) + 32                               #Convertir la variable C en Float para que sea de valor typo decimal y poder hacer la operación con la formula en type numeros y no texto.
print((C),"° en Fahrenheit es:",F)
# Out:
# ¿Cuantos grados celcius deseas convertir? 45
# 45.0 ° en Fahrenheit es: 113.0

# %% [markdown]
# ## Ejercicio 6
# Comenta en la medida de lo posible el Ejercicio 5. Será suficiente con poner al menos un comentario de línea, y otro multilínea

# %%
# Out:
# El equivalente en grados Fahrenheit es 41.0
