# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics II

# %% [markdown]
# ## Ejercicio 1
# * Crea dos variables numericas: un `int` y un `float`
# * Comprueba sus tipos
# * Sumalas en otra nueva
# * ¿De qué tipo es la nueva variable?
# * Elimina las dos primeras variables creadas

# %%
Completos = 230
Pi = 3.1416
print((Pi), type(Pi))
print((Completos), type(Completos))
print((Completos + Pi), type(Completos + Pi))
del(Completos, Pi)
print(Completos)
print(Pi)
# Out:
# 3.1416 <class 'float'>
# 230 <class 'int'>
# 233.1416 <class 'float'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 7
#       5 print((Completos + Pi), type(Completos + Pi))
#       6 del(Completos, Pi)
# ----> 7 print(Completos)
#       8 print(Pi)
#
# NameError: name 'Completos' is not defined

# %% [markdown]
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
Mensaje= ("¿Qué radianes son?")
G = float(input(Mensaje))
R = G*(math.pi/180)
print("Tus radianes son:",(R))
# Out:
# ¿Qué radianes son? 300
# Tus radianes son: 5.235987755982989

# %% [markdown]
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
import math

B = float(input("Dime la base")) 
A = float(input("Dime la altura"))
Area = (B * A) 
print("El area de tu paralelogramo es:",(Area))
# Out:
# Dime la base 54
# Dime la altura 563
# El area de tu paralelogramo es: 30402.0

# %% [markdown]
# ## Ejercicio 4
# Tenemos las siguientes variables:
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1

# %%
print(("1.", A == B),("2.", A != C),("3.", A > C),("4.", C <= A),("5.", B != C))
# Out:
# ('1.', False) ('2.', True) ('3.', False) ('4.', False) ('5.', True)

# %% [markdown]
# ## Ejercicio 5
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
Operador = input("¿Qué servicio de internet tiene usted en casa?")
Servicio = input("¿Qué operador movil tiene?")
print(("¿El operador movil y el servicio internet son los mismos"),(Operador == Servicio))
# Out:
# ¿Qué servicio de internet tiene usted en casa? Digi
# ¿Qué operador movil tiene? Digi
# ¿El operador movil y el servicio internet son los mismos True

# %% [markdown]
# ## Ejercicio 6
# Mismo programa que en 5, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
Linea1 = input("Dime tu linea: ")
Linea2 = input("Dime tu linea: ")
Linea3 = input("Dime tu linea: ")

todos_iguales = (Linea1 == Linea2 == Linea3)
al_menos_dos = (Linea1 == Linea2 or Linea2 == Linea3 or Linea1 == Linea3)

print(todos_iguales)
print(al_menos_dos)
# Out:
# Dime tu linea:  Digi
# Dime tu linea:  Vadafone
# Dime tu linea:  Digi
# False
# True

# %% [markdown]
# ## Ejercicio 7
# Crea un programa que recoja dos inputs. Tiene que comprobar si su suma es igual, superior o inferior a 10

# %%
ejerc7 = int(input("¿Qué numero deseas sumar?"))
suma7 = int(input("Dime otro numero, por favor que sea un numero entero"))
suma = ejerc7 + suma7
print(suma, "¿La suma es igual a 10?", suma == 10 )
print(suma, "¿La suma es superior a 10?",suma > 10)
print(suma, "¿La suma es inferior a 10?", suma < 10)
# Out:
# ¿Qué numero deseas sumar? 23
# Dime otro numero, por favor que sea un numero entero 4
# 27 ¿La suma es igual a 10? False
# 27 ¿La suma es superior a 10? True
# 27 ¿La suma es inferior a 10? False

# %% [markdown]
# ## Ejercicio 8
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %% [markdown]
# 1: False
# 2: Flase
# 3: Falso
# 4: Falso

# %% [markdown]
# ## Ejercicio 9
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
lista = [4, 6, 8, -1]
maximo = max(lista)
print(maximo) 
suma_total = sum(lista)
print(suma_total)
numero = 63.451256965
redondeado = round(numero, 3) 
print(redondeado)
valor = abs(-74)
print(valor)
# Out:
# 8
# 17
# 63.451
# 74

# %% [markdown]
# ## Ejercicio 10
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."
#
# 1. Pásalo todo a mayúsculas
# 2. Pásalo todo a minúsculas
# 3. Solo la primera letra de cada palabra en mayúscula, el resto en minúscula
# 4. Crea una lista dividiéndolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minúsculas

# %%
Ej= "En un lugar de la Mancha, de cuyo nombre no quiero acordarme."

print(Ej.upper())

print(Ej.lower())

print(Ej.title())

lista_espacios = Ej.split("( )")
print(lista_espacios)

print(Ej.replace(",", ";"))

print(Ej.replace("a", ""))
# Out:
# EN UN LUGAR DE LA MANCHA, DE CUYO NOMBRE NO QUIERO ACORDARME.
# en un lugar de la mancha, de cuyo nombre no quiero acordarme.
# En Un Lugar De La Mancha, De Cuyo Nombre No Quiero Acordarme.
# ['En un lugar de la Mancha, de cuyo nombre no quiero acordarme.']
# En un lugar de la Mancha; de cuyo nombre no quiero acordarme.
# En un lugr de l Mnch, de cuyo nombre no quiero cordrme.

# %% [markdown]
# ## Ejercicio 11
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.

# %%
# Out:
# 10
# [2, 3, 4]
# [2, 3, 5, 4]
# [2, 3, 5, 4, 6, 7, 8, 9]
